# %%
import matplotlib.pyplot as plt

# %%
VIS1_MEAN = 300.6
AUD1_MEAN = 424.4
VIS1_STD = 46.65
AUD1_STD = 35.87

# %%
# build a bar plot
plt.bar(['Person 1 Visual', 'Person 1 Auditory'],[VIS1_MEAN, AUD1_MEAN], yerr=[VIS1_STD, AUD1_STD], capsize=10)
plt.ylabel('Speed (msec)')
plt.xlabel("Reflex Type")
plt.title('Reflex Speed, Visual vs. Auditory')
# Out:
# Text(0.5, 1.0, 'Reflex Speed, Visual vs. Auditory')

# %%
VIS1_MEAN = 300.6
VIS2_MEAN = 214.7
VIS1_STD = 38.45
VIS2_STD = 31.1

# %%
# build a bar plot
plt.bar(['Person 1 Visual', 'Person 1 Visual'],[VIS1_MEAN, AUD1_MEAN], yerr=[VIS1_STD, AUD1_STD], capsize=10)
plt.ylabel('Speed (msec)')
plt.xlabel("Reflex Type")
plt.title('Reflex Speed, Visual vs. Auditory')
# Out:
# Text(0.5, 1.0, 'Reflex Speed, Visual vs. Auditory')
